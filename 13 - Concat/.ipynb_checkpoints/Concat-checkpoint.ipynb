# %%
import pandas as pd
df1 = pd.read_csv('bank.csv', encoding='utf-8', sep=';')
df2 = pd.read_csv('Dados aula 1.csv', encoding='utf-8', sep=';')

# %%
#Concatena duas dataframes
pd.concat([df1,df2]).head()
# Out:
#     age          job  marital  education default  balance housing loan  \
# 0  30.0   unemployed  married    primary      no   1787.0      no   no
# 1  33.0     services  married  secondary      no   4789.0     yes  yes
# 2  35.0   management   single   tertiary      no   1350.0     yes   no
# 3  30.0   management  married   tertiary      no   1476.0     yes  yes
# 4  59.0  blue-collar  married  secondary      no      0.0     yes   no
#
#     contact   day  ...   y  AddressID  AddressLine1  AddressLine2  City  \
# 0  cellular  19.0  ...  no        NaN           NaN           NaN   NaN
# 1  cellular  11.0  ...  no        NaN           NaN           NaN   NaN
# 2  cellular  16.0  ...  no        NaN           NaN           NaN   NaN
# 3   unknown   3.0  ...  no        NaN           NaN           NaN   NaN
# 4   unknown   5.0  ...  no        NaN           NaN           NaN   NaN
#
#   StateProvinceID PostalCode  SpatialLocation rowguid ModifiedDate
# ...

# %%
#Limpa e reseta os indices
pd.concat([df1,df2], ignore_index=True)
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0     30.0   unemployed  married    primary      no   1787.0      no   no
# 1     33.0     services  married  secondary      no   4789.0     yes  yes
# 2     35.0   management   single   tertiary      no   1350.0     yes   no
# 3     30.0   management  married   tertiary      no   1476.0     yes  yes
# 4     59.0  blue-collar  married  secondary      no      0.0     yes   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 5516   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 5517   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 5518   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 5519   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 5520   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
#
#        contact   day  ...    y  AddressID                 AddressLine1  \
# ...

# %%
#Adiciona um index hierarquico
pd.concat([df1,df2], keys=['primeiro','segundo'])
# Out:
#                age          job  marital  education default  balance housing  \
# primeiro 0    30.0   unemployed  married    primary      no   1787.0      no
#          1    33.0     services  married  secondary      no   4789.0     yes
#          2    35.0   management   single   tertiary      no   1350.0     yes
#          3    30.0   management  married   tertiary      no   1476.0     yes
#          4    59.0  blue-collar  married  secondary      no      0.0     yes
# ...            ...          ...      ...        ...     ...      ...     ...
# segundo  995   NaN          NaN      NaN        NaN     NaN      NaN     NaN
#          996   NaN          NaN      NaN        NaN     NaN      NaN     NaN
#          997   NaN          NaN      NaN        NaN     NaN      NaN     NaN
#          998   NaN          NaN      NaN        NaN     NaN      NaN     NaN
#          999   NaN          NaN      NaN        NaN     NaN      NaN     NaN
#
# ...

# %%
#names -> Nomeia os indices na hierarquia
pd.concat([df1,df2], keys=['primeiro','segundo'], names=['Tiranu','pao'])
# Out:
#                age          job  marital  education default  balance housing  \
# Tiranu   pao
# primeiro 0    30.0   unemployed  married    primary      no   1787.0      no
#          1    33.0     services  married  secondary      no   4789.0     yes
#          2    35.0   management   single   tertiary      no   1350.0     yes
#          3    30.0   management  married   tertiary      no   1476.0     yes
#          4    59.0  blue-collar  married  secondary      no      0.0     yes
# ...            ...          ...      ...        ...     ...      ...     ...
# segundo  995   NaN          NaN      NaN        NaN     NaN      NaN     NaN
#          996   NaN          NaN      NaN        NaN     NaN      NaN     NaN
#          997   NaN          NaN      NaN        NaN     NaN      NaN     NaN
#          998   NaN          NaN      NaN        NaN     NaN      NaN     NaN
#          999   NaN          NaN      NaN        NaN     NaN      NaN     NaN
#
# ...

# %%
df1.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df2.head()
# Out:
#    AddressID          AddressLine1 AddressLine2     City  StateProvinceID  \
# 0          1         1970 Napa Ct.          NaN  Bothell               79
# 1          2    9833 Mt. Dias Blv.          NaN  Bothell               79
# 2          3  7484 Roundtree Drive          NaN  Bothell               79
# 3          4      9539 Glenside Dr          NaN  Bothell               79
# 4          5         1226 Shoe St.          NaN  Bothell               79
#
#   PostalCode                                 SpatialLocation  \
# 0      98011  0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1      98011  0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
# 2      98011  0xE6100000010C18E304C4ADE14740DA930C7893915EC0
# 3      98011  0xE6100000010C813A0D5F9FDE474011A5C28A7C955EC0
# 4      98011  0xE6100000010C61C64D8ABBD94740C460EA3FD8855EC0
#
#                                 rowguid             ModifiedDate
# 0  9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# ...
