# %%
import pandas as pd
df = pd.read_csv('bank.csv', encoding='utf-8', sep=';')
df2 = pd.read_csv('Dados aula 1.csv', encoding='utf-8', sep=';')

# %%
df.merge(df2, left_on='day', right_on='StateProvinceID').head()
# Out:
#    age         job  marital education default  balance housing loan   contact  \
# 0   30  unemployed  married   primary      no     1787      no   no  cellular
# 1   30  unemployed  married   primary      no     1787      no   no  cellular
# 2   30  unemployed  married   primary      no     1787      no   no  cellular
# 3   30  unemployed  married   primary      no     1787      no   no  cellular
# 4   30  unemployed  married   primary      no     1787      no   no  cellular
#
#    day  ...   y  AddressID           AddressLine1  AddressLine2         City  \
# 0   19  ...  no        720        Kurfürstenstr 9           NaN  Duesseldorf
# 1   19  ...  no        721      Postfach 11 09 00           NaN       Berlin
# 2   19  ...  no        726      Kurfürstenstr 574           NaN      München
# 3   19  ...  no        727  Königsteiner Straße 9           NaN    Bad Soden
# 4   19  ...  no        734       Am Karlshof 8200           NaN      Hamburg
#
# ...

# %%
df.merge(df2, left_index=True, right_index=True)[['day','StateProvinceID']].head()
# Out:
#    day  StateProvinceID
# 0   19               79
# 1   11               79
# 2   16               79
# 3    3               79
# 4    5               79

# %%
df.merge(df2, left_on = ['day', 'duration'] , right_on = ['AddressID', 'StateProvinceID'])[['day', 'duration', 'AddressID','StateProvinceID']].head()
# Out:
#    day  duration  AddressID  StateProvinceID
# 0   19        79         19               79
# 1   19        79         19               79
# 2   19        79         19               79
# 3   18        79         18               79
# 4   18        79         18               79

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df2.head()
# Out:
#    AddressID          AddressLine1 AddressLine2     City  StateProvinceID  \
# 0          1         1970 Napa Ct.          NaN  Bothell               79
# 1          2    9833 Mt. Dias Blv.          NaN  Bothell               79
# 2          3  7484 Roundtree Drive          NaN  Bothell               79
# 3          4      9539 Glenside Dr          NaN  Bothell               79
# 4          5         1226 Shoe St.          NaN  Bothell               79
#
#   PostalCode                                 SpatialLocation  \
# 0      98011  0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1      98011  0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
# 2      98011  0xE6100000010C18E304C4ADE14740DA930C7893915EC0
# 3      98011  0xE6100000010C813A0D5F9FDE474011A5C28A7C955EC0
# 4      98011  0xE6100000010C61C64D8ABBD94740C460EA3FD8855EC0
#
#                                 rowguid             ModifiedDate
# 0  9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# ...
